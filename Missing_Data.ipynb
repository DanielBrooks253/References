# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno

# %%
df = pd.read_csv('titanic3.csv')
orig_df = df
df.isnull().mean()*100
# Out:
# pclass        0.000000
# survived      0.000000
# name          0.000000
# sex           0.000000
# age          20.091673
# sibsp         0.000000
# parch         0.000000
# ticket        0.000000
# fare          0.076394
# cabin        77.463713
# embarked      0.152788
# boat         62.872422
# body         90.756303
# home.dest    43.086325
# dtype: float64

# %%
msno.matrix(orig_df.sample(500))
# Out:
# <AxesSubplot:>

# %%
msno.bar(orig_df.sample(500))
# Out:
# <AxesSubplot:>

# %%
# Correlation between where the data is missining
msno.heatmap(df, figsize=(6, 6))
# Out:
# <AxesSubplot:>

# %%
msno.dendrogram(df)
# Out:
# <AxesSubplot:>
